# %%
import pandas as pd
import numpy as np
import os
import pickle
from IPython.display import Image, display
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, LSTM, Bidirectional, Dropout, Input, AdditiveAttention, GlobalAveragePooling1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mahadidn/wind-speed-forecasting/refs/heads/main/datasets/1994_2025_multivariat.csv')
df.head(5)
# Out:
#       TANGGAL  TAVG  RH_AVG  FF_AVG
# 0  1994-03-01  28.4    72.0    11.0
# 1  1994-03-02  27.7    76.0    10.0
# 2  1994-03-03  27.7    79.0     9.0
# 3  1994-03-04  26.0    90.0     5.0
# 4  1994-03-05  23.3    96.0     3.0

# %%
# Pembagian data 70% training, 20% validasi, dan 10% testing
n = len(df)
n_train = int(n * 0.70)
n_val   = int(n * 0.20)
n_test  = n - n_train - n_val

train_df = df.iloc[:n_train].copy()
val_df   = df.iloc[n_train : n_train + n_val].copy()
test_df  = df.iloc[n_train + n_val :].copy()

# %%
# fitur dan target
input_features = ['FF_AVG', 'TAVG', 'RH_AVG']
target_feature = 'FF_AVG'

# %%
X_train = train_df[input_features].values
X_val = val_df[input_features].values
X_test = test_df[input_features].values

y_train = train_df[target_feature].values
y_val = val_df[target_feature].values
y_test = test_df[target_feature].values

print(f"\nData shapes:")
print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
print(f"X_val: {X_val.shape}, y_val: {y_val.shape}")
print(f"X_test: {X_test.shape}, y_test: {y_test.shape}")
# Out:
# Data shapes:
# X_train: (7947, 3), y_train: (7947,)
# X_val: (2270, 3), y_val: (2270,)
# X_test: (1137, 3), y_test: (1137,)

# %%
# Data scaling menggunakan min-max
X_scaler = MinMaxScaler()
X_train_scaled = X_scaler.fit_transform(X_train)
X_val_scaled = X_scaler.transform(X_val)
X_test_scaled = X_scaler.transform(X_test)

y_scaler = MinMaxScaler()
y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, 1)).flatten()
y_val_scaled = y_scaler.transform(y_val.reshape(-1, 1)).flatten()
y_test_scaled = y_scaler.transform(y_test.reshape(-1, 1)).flatten()

# Save scalers
os.makedirs('models', exist_ok=True)
with open("models/X_scaler_multivariate.pkl", "wb") as f:
    pickle.dump(X_scaler, f)

with open("models/y_scaler_multivariate.pkl", "wb") as f:
    pickle.dump(y_scaler, f)

# %%
# membuat sliding window untuk multistep forecasting
def create_multistep_sequences(X, y, time_steps, forecast_horizon):
    """Create sequences for multi-step multivariate time series prediction"""
    if len(X) <= time_steps + forecast_horizon:
        raise ValueError(f"Panjang data ({len(X)}) harus lebih dari time_steps + forecast_horizon ({time_steps + forecast_horizon})")

    Xs, ys = [], []
    for i in range(len(X) - time_steps - forecast_horizon + 1):
        # Input sequence multivariat (time_steps, n_features)
        Xs.append(X[i : (i + time_steps)])
        # Output sequence: univariat (forecast_horizon,)
        ys.append(y[i + time_steps : i + time_steps + forecast_horizon])

    return np.array(Xs), np.array(ys)

# Multi-step forecasting parameters
time_steps = 60        # menggunakan 60 hari data historis
forecast_horizon = 30  # prediksi 30 hari ke depan

# Buat multi-step sequences (MULTIVARIAT)
X_train_seq, y_train_seq = create_multistep_sequences(X_train_scaled, y_train_scaled, time_steps, forecast_horizon)
X_val_seq, y_val_seq = create_multistep_sequences(X_val_scaled, y_val_scaled, time_steps, forecast_horizon)
X_test_seq, y_test_seq = create_multistep_sequences(X_test_scaled, y_test_scaled, time_steps, forecast_horizon)

print(f"\nMultivariate sequences shapes:")
print(f"Multi-step sequences shapes:")
print(f"X_train_seq: {X_train_seq.shape}, y_train_seq: {y_train_seq.shape}")
print(f"X_val_seq: {X_val_seq.shape}, y_val_seq: {y_val_seq.shape}")
print(f"X_test_seq: {X_test_seq.shape}, y_test_seq: {y_test_seq.shape}")
# Out:
# Multivariate sequences shapes:
# Multi-step sequences shapes:
# X_train_seq: (7858, 60, 3), y_train_seq: (7858, 30)
# X_val_seq: (2181, 60, 3), y_val_seq: (2181, 30)
# X_test_seq: (1048, 60, 3), y_test_seq: (1048, 30)

# %%
# Evaluasi Multi-step
def calculate_multistep_metrics(y_true, y_pred):
    """Hitung metrik evaluasi untuk multi-step forecasting"""

    metrics = {}
    n_steps = y_true.shape[1]

    # Keseluruhan metrik
    y_true_flat = y_true.flatten()
    y_pred_flat = y_pred.flatten()

    metrics['keseluruhan'] = {
        'mae': mean_absolute_error(y_true_flat, y_pred_flat),
        'mape': mean_absolute_percentage_error(y_true_flat, y_pred_flat) * 100,
        'rmse': np.sqrt(mean_squared_error(y_true_flat, y_pred_flat))
    }

    # metrik tiap langkah
    metrics['langkah'] = {}
    for step in range(n_steps):
        step_true = y_true[:, step]
        step_pred = y_pred[:, step]

        metrics['langkah'][f'step_{step+1}'] = {
            'mae': mean_absolute_error(step_true, step_pred),
            'mape': mean_absolute_percentage_error(step_true, step_pred) * 100,
            'rmse': np.sqrt(mean_squared_error(step_true, step_pred))
        }

    return metrics

# %%
# Model BiLSTM-Attention untuk MULTIVARIAT
def create_multivariate_bilstm_attention(time_steps=60, forecast_horizon=30, fitur=3, learning_rate=0.0001):
    """
    Buat model BiLSTM-Attention untuk multivariate input, univariate output

    Parameters:
    - time_steps : jumlah time steps untuk input
    - forecast_horizon: jumlah steps untuk prediksi
    - fitur: jumlah input features (3 untuk FF_AVG, TAVG, RH_AVG)
    - learning_rate = learning rate untuk optimizer
    """

    # Input shape: (time_steps, n_features)
    inputs = Input(shape=(time_steps, fitur))
    print(f"Model input shape: {inputs}")

    # BiLSTM layers
    x = Bidirectional(LSTM(64, return_sequences=True, kernel_regularizer=tf.keras.regularizers.L2(1e-3)))(inputs)
    x = Bidirectional(LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.L2(1e-3)))(x)


    # Attention mechanism
    context_vector = AdditiveAttention(name='attention_layer')([x, x])

    # Global average pooling untuk reduksi dimensi
    context_vector = GlobalAveragePooling1D()(context_vector)

    # Fully connected layers
    dense_1 = Dense(64, activation='relu')(context_vector)
    # Output layer
    output = Dense(forecast_horizon, activation='linear')(dense_1)

    # Create model
    model = Model(inputs=inputs, outputs=output, name='Multivariate_BiLSTM_Attention')

    # Compile model
    model.compile(
        optimizer=Adam(learning_rate=learning_rate, clipnorm=1.0),
        loss='mse',
        metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.RootMeanSquaredError()]
    )

    return model

# %%
models = {}
histories = {}
metrics = {}
results = []

for learning_rate in [0.0001]:
    for epochs in [200]:
        config_name = f'learning_rate_{learning_rate}_epochs_{epochs}'
        print(f"\nTraining model: {config_name}")

        # Setup direktori penyimpanan
        os.makedirs("models", exist_ok=True)
        os.makedirs("histories", exist_ok=True)
        os.makedirs("metrics", exist_ok=True)

        # Buat model
        model = create_multivariate_bilstm_attention(
            time_steps=X_train_seq.shape[1],
            forecast_horizon=forecast_horizon,
            fitur=X_train_seq.shape[2],
            learning_rate=learning_rate
        )

        model.summary()

        # Training
        history = model.fit(
            X_train_seq, y_train_seq,
            validation_data=(X_val_seq, y_val_seq),
            epochs=epochs,
            batch_size=64,
            shuffle=False
        )

        # Simpan model ke file .keras
        model.save(f"models/{config_name}.keras")

        # Simpan history ke file .pkl
        with open(f"histories/{config_name}_history.pkl", 'wb') as f:
            pickle.dump(history, f)

        # Simpan ke dictionary (opsional, in-memory)
        models[config_name] = model
        histories[config_name] = history

print("\nSemua model, history, dan hasil evaluasi disimpan.")
# Out:
# Training model: learning_rate_0.0001_epochs_200
# Model input shape: <KerasTensor shape=(None, 60, 3), dtype=float32, sparse=False, name=keras_tensor>
# Model: "Multivariate_BiLSTM_Attention"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 60, 3)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 60, 128)   │     34,816 │ input_layer[0][0] │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 60, 64)    │     41,216 │ bidirectional[0]… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_layer     │ (None, 60, 64)    │         64 │ bidirectional_1[… │
# │ (AdditiveAttention) │                   │            │ bidirectional_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ attention_layer[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │      4,160 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 30)        │      1,950 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 82,206 (321.12 KB)
#  Trainable params: 82,206 (321.12 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 0.3213 - mean_absolute_error: 0.2126 - root_mean_squared_error: 0.2551 - val_loss: 0.2339 - val_mean_absolute_error: 0.1074 - val_root_mean_squared_error: 0.1282
# Epoch 2/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.2240 - mean_absolute_error: 0.1058 - root_mean_squared_error: 0.1346 - val_loss: 0.1856 - val_mean_absolute_error: 0.0926 - val_root_mean_squared_error: 0.1104
# Epoch 3/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.1779 - mean_absolute_error: 0.0924 - root_mean_squared_error: 0.1180 - val_loss: 0.1469 - val_mean_absolute_error: 0.0748 - val_root_mean_squared_error: 0.0968
# Epoch 4/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.1424 - mean_absolute_error: 0.0872 - root_mean_squared_error: 0.1121 - val_loss: 0.1176 - val_mean_absolute_error: 0.0739 - val_root_mean_squared_error: 0.0960
# Epoch 5/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.1146 - mean_absolute_error: 0.0863 - root_mean_squared_error: 0.1114 - val_loss: 0.0942 - val_mean_absolute_error: 0.0736 - val_root_mean_squared_error: 0.0960
# Epoch 6/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0923 - mean_absolute_error: 0.0858 - root_mean_squared_error: 0.1109 - val_loss: 0.0753 - val_mean_absolute_error: 0.0728 - val_root_mean_squared_error: 0.0952
# Epoch 7/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0743 - mean_absolute_error: 0.0848 - root_mean_squared_error: 0.1098 - val_loss: 0.0601 - val_mean_absolute_error: 0.0725 - val_root_mean_squared_error: 0.0941
# Epoch 8/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0602 - mean_absolute_error: 0.0850 - root_mean_squared_error: 0.1100 - val_loss: 0.0485 - val_mean_absolute_error: 0.0724 - val_root_mean_squared_error: 0.0949
# Epoch 9/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0490 - mean_absolute_error: 0.0845 - root_mean_squared_error: 0.1095 - val_loss: 0.0392 - val_mean_absolute_error: 0.0723 - val_root_mean_squared_error: 0.0946
# Epoch 10/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0401 - mean_absolute_error: 0.0834 - root_mean_squared_error: 0.1082 - val_loss: 0.0323 - val_mean_absolute_error: 0.0730 - val_root_mean_squared_error: 0.0955
# Epoch 11/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0335 - mean_absolute_error: 0.0839 - root_mean_squared_error: 0.1087 - val_loss: 0.0265 - val_mean_absolute_error: 0.0747 - val_root_mean_squared_error: 0.0938
# Epoch 12/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0283 - mean_absolute_error: 0.0840 - root_mean_squared_error: 0.1084 - val_loss: 0.0223 - val_mean_absolute_error: 0.0736 - val_root_mean_squared_error: 0.0937
# Epoch 13/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0244 - mean_absolute_error: 0.0834 - root_mean_squared_error: 0.1081 - val_loss: 0.0194 - val_mean_absolute_error: 0.0741 - val_root_mean_squared_error: 0.0948
# Epoch 14/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0213 - mean_absolute_error: 0.0826 - root_mean_squared_error: 0.1071 - val_loss: 0.0174 - val_mean_absolute_error: 0.0790 - val_root_mean_squared_error: 0.0964
# Epoch 15/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0192 - mean_absolute_error: 0.0831 - root_mean_squared_error: 0.1074 - val_loss: 0.0153 - val_mean_absolute_error: 0.0754 - val_root_mean_squared_error: 0.0943
# Epoch 16/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0177 - mean_absolute_error: 0.0835 - root_mean_squared_error: 0.1078 - val_loss: 0.0139 - val_mean_absolute_error: 0.0748 - val_root_mean_squared_error: 0.0934
# Epoch 17/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0165 - mean_absolute_error: 0.0835 - root_mean_squared_error: 0.1077 - val_loss: 0.0128 - val_mean_absolute_error: 0.0726 - val_root_mean_squared_error: 0.0926
# Epoch 18/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0153 - mean_absolute_error: 0.0823 - root_mean_squared_error: 0.1064 - val_loss: 0.0121 - val_mean_absolute_error: 0.0742 - val_root_mean_squared_error: 0.0929
# Epoch 19/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0147 - mean_absolute_error: 0.0826 - root_mean_squared_error: 0.1064 - val_loss: 0.0115 - val_mean_absolute_error: 0.0733 - val_root_mean_squared_error: 0.0921
# Epoch 20/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0143 - mean_absolute_error: 0.0824 - root_mean_squared_error: 0.1066 - val_loss: 0.0111 - val_mean_absolute_error: 0.0730 - val_root_mean_squared_error: 0.0922
# Epoch 21/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0140 - mean_absolute_error: 0.0826 - root_mean_squared_error: 0.1068 - val_loss: 0.0111 - val_mean_absolute_error: 0.0757 - val_root_mean_squared_error: 0.0936
# Epoch 22/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0139 - mean_absolute_error: 0.0833 - root_mean_squared_error: 0.1075 - val_loss: 0.0108 - val_mean_absolute_error: 0.0729 - val_root_mean_squared_error: 0.0928
# Epoch 23/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0134 - mean_absolute_error: 0.0822 - root_mean_squared_error: 0.1063 - val_loss: 0.0104 - val_mean_absolute_error: 0.0726 - val_root_mean_squared_error: 0.0920
# Epoch 24/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0133 - mean_absolute_error: 0.0824 - root_mean_squared_error: 0.1065 - val_loss: 0.0102 - val_mean_absolute_error: 0.0717 - val_root_mean_squared_error: 0.0914
# Epoch 25/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0130 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1057 - val_loss: 0.0101 - val_mean_absolute_error: 0.0719 - val_root_mean_squared_error: 0.0913
# Epoch 26/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0130 - mean_absolute_error: 0.0820 - root_mean_squared_error: 0.1062 - val_loss: 0.0101 - val_mean_absolute_error: 0.0720 - val_root_mean_squared_error: 0.0918
# Epoch 27/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0130 - mean_absolute_error: 0.0824 - root_mean_squared_error: 0.1067 - val_loss: 0.0101 - val_mean_absolute_error: 0.0721 - val_root_mean_squared_error: 0.0924
# Epoch 28/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0127 - mean_absolute_error: 0.0817 - root_mean_squared_error: 0.1057 - val_loss: 0.0098 - val_mean_absolute_error: 0.0724 - val_root_mean_squared_error: 0.0914
# Epoch 29/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0127 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1061 - val_loss: 0.0099 - val_mean_absolute_error: 0.0735 - val_root_mean_squared_error: 0.0922
# Epoch 30/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0128 - mean_absolute_error: 0.0828 - root_mean_squared_error: 0.1069 - val_loss: 0.0099 - val_mean_absolute_error: 0.0746 - val_root_mean_squared_error: 0.0925
# Epoch 31/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0126 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1058 - val_loss: 0.0096 - val_mean_absolute_error: 0.0719 - val_root_mean_squared_error: 0.0910
# Epoch 32/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0125 - mean_absolute_error: 0.0818 - root_mean_squared_error: 0.1060 - val_loss: 0.0096 - val_mean_absolute_error: 0.0713 - val_root_mean_squared_error: 0.0915
# Epoch 33/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0124 - mean_absolute_error: 0.0817 - root_mean_squared_error: 0.1058 - val_loss: 0.0097 - val_mean_absolute_error: 0.0739 - val_root_mean_squared_error: 0.0922
# Epoch 34/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0125 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1060 - val_loss: 0.0096 - val_mean_absolute_error: 0.0729 - val_root_mean_squared_error: 0.0919
# Epoch 35/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0124 - mean_absolute_error: 0.0820 - root_mean_squared_error: 0.1060 - val_loss: 0.0094 - val_mean_absolute_error: 0.0709 - val_root_mean_squared_error: 0.0910
# Epoch 36/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0123 - mean_absolute_error: 0.0817 - root_mean_squared_error: 0.1059 - val_loss: 0.0093 - val_mean_absolute_error: 0.0713 - val_root_mean_squared_error: 0.0908
# Epoch 37/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0125 - mean_absolute_error: 0.0825 - root_mean_squared_error: 0.1068 - val_loss: 0.0096 - val_mean_absolute_error: 0.0743 - val_root_mean_squared_error: 0.0923
# Epoch 38/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0123 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1058 - val_loss: 0.0094 - val_mean_absolute_error: 0.0730 - val_root_mean_squared_error: 0.0914
# Epoch 39/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0125 - mean_absolute_error: 0.0827 - root_mean_squared_error: 0.1069 - val_loss: 0.0096 - val_mean_absolute_error: 0.0748 - val_root_mean_squared_error: 0.0926
# Epoch 40/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0123 - mean_absolute_error: 0.0820 - root_mean_squared_error: 0.1062 - val_loss: 0.0094 - val_mean_absolute_error: 0.0730 - val_root_mean_squared_error: 0.0920
# Epoch 41/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0121 - mean_absolute_error: 0.0816 - root_mean_squared_error: 0.1057 - val_loss: 0.0094 - val_mean_absolute_error: 0.0717 - val_root_mean_squared_error: 0.0918
# Epoch 42/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0122 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1060 - val_loss: 0.0093 - val_mean_absolute_error: 0.0712 - val_root_mean_squared_error: 0.0916
# Epoch 43/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0124 - mean_absolute_error: 0.0825 - root_mean_squared_error: 0.1069 - val_loss: 0.0092 - val_mean_absolute_error: 0.0712 - val_root_mean_squared_error: 0.0909
# Epoch 44/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0121 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1060 - val_loss: 0.0092 - val_mean_absolute_error: 0.0707 - val_root_mean_squared_error: 0.0914
# Epoch 45/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0121 - mean_absolute_error: 0.0821 - root_mean_squared_error: 0.1061 - val_loss: 0.0093 - val_mean_absolute_error: 0.0715 - val_root_mean_squared_error: 0.0918
# Epoch 46/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0118 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1048 - val_loss: 0.0091 - val_mean_absolute_error: 0.0711 - val_root_mean_squared_error: 0.0908
# Epoch 47/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0121 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1061 - val_loss: 0.0093 - val_mean_absolute_error: 0.0717 - val_root_mean_squared_error: 0.0920
# Epoch 48/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0121 - mean_absolute_error: 0.0821 - root_mean_squared_error: 0.1062 - val_loss: 0.0093 - val_mean_absolute_error: 0.0718 - val_root_mean_squared_error: 0.0922
# Epoch 49/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0122 - mean_absolute_error: 0.0824 - root_mean_squared_error: 0.1065 - val_loss: 0.0093 - val_mean_absolute_error: 0.0712 - val_root_mean_squared_error: 0.0921
# Epoch 50/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0120 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1057 - val_loss: 0.0092 - val_mean_absolute_error: 0.0718 - val_root_mean_squared_error: 0.0917
# Epoch 51/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 0.0119 - mean_absolute_error: 0.0813 - root_mean_squared_error: 0.1054 - val_loss: 0.0090 - val_mean_absolute_error: 0.0711 - val_root_mean_squared_error: 0.0907
# Epoch 52/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.0120 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1059 - val_loss: 0.0091 - val_mean_absolute_error: 0.0724 - val_root_mean_squared_error: 0.0917
# Epoch 53/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0119 - mean_absolute_error: 0.0816 - root_mean_squared_error: 0.1056 - val_loss: 0.0092 - val_mean_absolute_error: 0.0736 - val_root_mean_squared_error: 0.0918
# Epoch 54/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0120 - mean_absolute_error: 0.0820 - root_mean_squared_error: 0.1062 - val_loss: 0.0089 - val_mean_absolute_error: 0.0708 - val_root_mean_squared_error: 0.0906
# Epoch 55/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0119 - mean_absolute_error: 0.0818 - root_mean_squared_error: 0.1059 - val_loss: 0.0090 - val_mean_absolute_error: 0.0722 - val_root_mean_squared_error: 0.0913
# Epoch 56/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0117 - mean_absolute_error: 0.0812 - root_mean_squared_error: 0.1051 - val_loss: 0.0092 - val_mean_absolute_error: 0.0719 - val_root_mean_squared_error: 0.0924
# Epoch 57/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0119 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1061 - val_loss: 0.0094 - val_mean_absolute_error: 0.0760 - val_root_mean_squared_error: 0.0936
# Epoch 58/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0118 - mean_absolute_error: 0.0818 - root_mean_squared_error: 0.1056 - val_loss: 0.0088 - val_mean_absolute_error: 0.0704 - val_root_mean_squared_error: 0.0900
# Epoch 59/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0119 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1059 - val_loss: 0.0089 - val_mean_absolute_error: 0.0711 - val_root_mean_squared_error: 0.0906
# Epoch 60/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0119 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1061 - val_loss: 0.0091 - val_mean_absolute_error: 0.0733 - val_root_mean_squared_error: 0.0918
# Epoch 61/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0118 - mean_absolute_error: 0.0816 - root_mean_squared_error: 0.1055 - val_loss: 0.0089 - val_mean_absolute_error: 0.0711 - val_root_mean_squared_error: 0.0911
# Epoch 62/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0117 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1054 - val_loss: 0.0090 - val_mean_absolute_error: 0.0727 - val_root_mean_squared_error: 0.0915
# Epoch 63/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0118 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1059 - val_loss: 0.0088 - val_mean_absolute_error: 0.0712 - val_root_mean_squared_error: 0.0905
# Epoch 64/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0117 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1052 - val_loss: 0.0089 - val_mean_absolute_error: 0.0717 - val_root_mean_squared_error: 0.0911
# Epoch 65/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0118 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1059 - val_loss: 0.0089 - val_mean_absolute_error: 0.0705 - val_root_mean_squared_error: 0.0913
# Epoch 66/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0117 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1055 - val_loss: 0.0088 - val_mean_absolute_error: 0.0704 - val_root_mean_squared_error: 0.0909
# Epoch 67/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0116 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1048 - val_loss: 0.0090 - val_mean_absolute_error: 0.0729 - val_root_mean_squared_error: 0.0916
# Epoch 68/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0117 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1054 - val_loss: 0.0089 - val_mean_absolute_error: 0.0713 - val_root_mean_squared_error: 0.0913
# Epoch 69/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0117 - mean_absolute_error: 0.0817 - root_mean_squared_error: 0.1057 - val_loss: 0.0092 - val_mean_absolute_error: 0.0714 - val_root_mean_squared_error: 0.0929
# Epoch 70/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0119 - mean_absolute_error: 0.0823 - root_mean_squared_error: 0.1065 - val_loss: 0.0088 - val_mean_absolute_error: 0.0710 - val_root_mean_squared_error: 0.0910
# Epoch 71/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0117 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1056 - val_loss: 0.0090 - val_mean_absolute_error: 0.0739 - val_root_mean_squared_error: 0.0921
# Epoch 72/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0118 - mean_absolute_error: 0.0821 - root_mean_squared_error: 0.1061 - val_loss: 0.0088 - val_mean_absolute_error: 0.0706 - val_root_mean_squared_error: 0.0910
# Epoch 73/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0118 - mean_absolute_error: 0.0818 - root_mean_squared_error: 0.1061 - val_loss: 0.0089 - val_mean_absolute_error: 0.0729 - val_root_mean_squared_error: 0.0914
# Epoch 74/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0117 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1055 - val_loss: 0.0089 - val_mean_absolute_error: 0.0718 - val_root_mean_squared_error: 0.0914
# Epoch 75/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0117 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1059 - val_loss: 0.0088 - val_mean_absolute_error: 0.0723 - val_root_mean_squared_error: 0.0911
# Epoch 76/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0116 - mean_absolute_error: 0.0812 - root_mean_squared_error: 0.1053 - val_loss: 0.0087 - val_mean_absolute_error: 0.0712 - val_root_mean_squared_error: 0.0907
# Epoch 77/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0116 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1053 - val_loss: 0.0089 - val_mean_absolute_error: 0.0717 - val_root_mean_squared_error: 0.0916
# Epoch 78/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0116 - mean_absolute_error: 0.0813 - root_mean_squared_error: 0.1052 - val_loss: 0.0087 - val_mean_absolute_error: 0.0709 - val_root_mean_squared_error: 0.0906
# Epoch 79/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0116 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1053 - val_loss: 0.0091 - val_mean_absolute_error: 0.0722 - val_root_mean_squared_error: 0.0925
# Epoch 80/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0116 - mean_absolute_error: 0.0812 - root_mean_squared_error: 0.1052 - val_loss: 0.0087 - val_mean_absolute_error: 0.0714 - val_root_mean_squared_error: 0.0908
# Epoch 81/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0116 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1054 - val_loss: 0.0088 - val_mean_absolute_error: 0.0715 - val_root_mean_squared_error: 0.0913
# Epoch 82/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0115 - mean_absolute_error: 0.0812 - root_mean_squared_error: 0.1051 - val_loss: 0.0088 - val_mean_absolute_error: 0.0729 - val_root_mean_squared_error: 0.0914
# Epoch 83/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0115 - mean_absolute_error: 0.0810 - root_mean_squared_error: 0.1050 - val_loss: 0.0087 - val_mean_absolute_error: 0.0719 - val_root_mean_squared_error: 0.0910
# Epoch 84/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0117 - mean_absolute_error: 0.0816 - root_mean_squared_error: 0.1058 - val_loss: 0.0088 - val_mean_absolute_error: 0.0723 - val_root_mean_squared_error: 0.0912
# Epoch 85/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0115 - mean_absolute_error: 0.0813 - root_mean_squared_error: 0.1051 - val_loss: 0.0087 - val_mean_absolute_error: 0.0716 - val_root_mean_squared_error: 0.0909
# Epoch 86/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0117 - mean_absolute_error: 0.0820 - root_mean_squared_error: 0.1061 - val_loss: 0.0088 - val_mean_absolute_error: 0.0720 - val_root_mean_squared_error: 0.0911
# Epoch 87/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0116 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1056 - val_loss: 0.0087 - val_mean_absolute_error: 0.0704 - val_root_mean_squared_error: 0.0909
# Epoch 88/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0114 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1048 - val_loss: 0.0089 - val_mean_absolute_error: 0.0739 - val_root_mean_squared_error: 0.0922
# Epoch 89/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0115 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1053 - val_loss: 0.0089 - val_mean_absolute_error: 0.0730 - val_root_mean_squared_error: 0.0920
# Epoch 90/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0116 - mean_absolute_error: 0.0818 - root_mean_squared_error: 0.1057 - val_loss: 0.0087 - val_mean_absolute_error: 0.0715 - val_root_mean_squared_error: 0.0907
# Epoch 91/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0116 - mean_absolute_error: 0.0818 - root_mean_squared_error: 0.1059 - val_loss: 0.0087 - val_mean_absolute_error: 0.0713 - val_root_mean_squared_error: 0.0907
# Epoch 92/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0116 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1056 - val_loss: 0.0086 - val_mean_absolute_error: 0.0708 - val_root_mean_squared_error: 0.0906
# Epoch 93/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0116 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1056 - val_loss: 0.0088 - val_mean_absolute_error: 0.0732 - val_root_mean_squared_error: 0.0915
# Epoch 94/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0115 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1054 - val_loss: 0.0091 - val_mean_absolute_error: 0.0753 - val_root_mean_squared_error: 0.0931
# Epoch 95/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0116 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1056 - val_loss: 0.0087 - val_mean_absolute_error: 0.0725 - val_root_mean_squared_error: 0.0913
# Epoch 96/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0114 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1049 - val_loss: 0.0087 - val_mean_absolute_error: 0.0725 - val_root_mean_squared_error: 0.0911
# Epoch 97/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0115 - mean_absolute_error: 0.0812 - root_mean_squared_error: 0.1051 - val_loss: 0.0092 - val_mean_absolute_error: 0.0764 - val_root_mean_squared_error: 0.0936
# Epoch 98/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0116 - mean_absolute_error: 0.0817 - root_mean_squared_error: 0.1057 - val_loss: 0.0088 - val_mean_absolute_error: 0.0735 - val_root_mean_squared_error: 0.0917
# Epoch 99/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0113 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1047 - val_loss: 0.0086 - val_mean_absolute_error: 0.0716 - val_root_mean_squared_error: 0.0908
# Epoch 100/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0114 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1050 - val_loss: 0.0090 - val_mean_absolute_error: 0.0754 - val_root_mean_squared_error: 0.0929
# Epoch 101/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0115 - mean_absolute_error: 0.0817 - root_mean_squared_error: 0.1055 - val_loss: 0.0089 - val_mean_absolute_error: 0.0739 - val_root_mean_squared_error: 0.0920
# Epoch 102/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0114 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1049 - val_loss: 0.0087 - val_mean_absolute_error: 0.0729 - val_root_mean_squared_error: 0.0914
# Epoch 103/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0115 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1053 - val_loss: 0.0087 - val_mean_absolute_error: 0.0721 - val_root_mean_squared_error: 0.0914
# Epoch 104/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0116 - mean_absolute_error: 0.0819 - root_mean_squared_error: 0.1058 - val_loss: 0.0087 - val_mean_absolute_error: 0.0715 - val_root_mean_squared_error: 0.0910
# Epoch 105/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0114 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1049 - val_loss: 0.0087 - val_mean_absolute_error: 0.0728 - val_root_mean_squared_error: 0.0915
# Epoch 106/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0114 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1051 - val_loss: 0.0086 - val_mean_absolute_error: 0.0707 - val_root_mean_squared_error: 0.0908
# Epoch 107/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0114 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1050 - val_loss: 0.0087 - val_mean_absolute_error: 0.0718 - val_root_mean_squared_error: 0.0911
# Epoch 108/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0113 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1047 - val_loss: 0.0086 - val_mean_absolute_error: 0.0708 - val_root_mean_squared_error: 0.0907
# Epoch 109/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0115 - mean_absolute_error: 0.0818 - root_mean_squared_error: 0.1056 - val_loss: 0.0086 - val_mean_absolute_error: 0.0714 - val_root_mean_squared_error: 0.0909
# Epoch 110/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0114 - mean_absolute_error: 0.0812 - root_mean_squared_error: 0.1052 - val_loss: 0.0088 - val_mean_absolute_error: 0.0737 - val_root_mean_squared_error: 0.0919
# Epoch 111/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0116 - mean_absolute_error: 0.0822 - root_mean_squared_error: 0.1062 - val_loss: 0.0088 - val_mean_absolute_error: 0.0729 - val_root_mean_squared_error: 0.0917
# Epoch 112/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0114 - mean_absolute_error: 0.0810 - root_mean_squared_error: 0.1050 - val_loss: 0.0086 - val_mean_absolute_error: 0.0712 - val_root_mean_squared_error: 0.0909
# Epoch 113/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0113 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1046 - val_loss: 0.0087 - val_mean_absolute_error: 0.0726 - val_root_mean_squared_error: 0.0915
# Epoch 114/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0113 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1046 - val_loss: 0.0087 - val_mean_absolute_error: 0.0721 - val_root_mean_squared_error: 0.0915
# Epoch 115/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0114 - mean_absolute_error: 0.0813 - root_mean_squared_error: 0.1053 - val_loss: 0.0088 - val_mean_absolute_error: 0.0726 - val_root_mean_squared_error: 0.0918
# Epoch 116/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0115 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1057 - val_loss: 0.0088 - val_mean_absolute_error: 0.0724 - val_root_mean_squared_error: 0.0917
# Epoch 117/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0114 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1054 - val_loss: 0.0090 - val_mean_absolute_error: 0.0752 - val_root_mean_squared_error: 0.0931
# Epoch 118/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0114 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1053 - val_loss: 0.0087 - val_mean_absolute_error: 0.0723 - val_root_mean_squared_error: 0.0917
# Epoch 119/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0114 - mean_absolute_error: 0.0813 - root_mean_squared_error: 0.1052 - val_loss: 0.0088 - val_mean_absolute_error: 0.0732 - val_root_mean_squared_error: 0.0919
# Epoch 120/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0113 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1049 - val_loss: 0.0086 - val_mean_absolute_error: 0.0715 - val_root_mean_squared_error: 0.0910
# Epoch 121/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0113 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1049 - val_loss: 0.0086 - val_mean_absolute_error: 0.0707 - val_root_mean_squared_error: 0.0907
# Epoch 122/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0113 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1048 - val_loss: 0.0086 - val_mean_absolute_error: 0.0702 - val_root_mean_squared_error: 0.0907
# Epoch 123/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0112 - mean_absolute_error: 0.0804 - root_mean_squared_error: 0.1041 - val_loss: 0.0086 - val_mean_absolute_error: 0.0725 - val_root_mean_squared_error: 0.0912
# Epoch 124/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0113 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1046 - val_loss: 0.0087 - val_mean_absolute_error: 0.0727 - val_root_mean_squared_error: 0.0914
# Epoch 125/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0114 - mean_absolute_error: 0.0813 - root_mean_squared_error: 0.1052 - val_loss: 0.0085 - val_mean_absolute_error: 0.0700 - val_root_mean_squared_error: 0.0907
# Epoch 126/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0113 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1048 - val_loss: 0.0086 - val_mean_absolute_error: 0.0705 - val_root_mean_squared_error: 0.0909
# Epoch 127/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0114 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1051 - val_loss: 0.0086 - val_mean_absolute_error: 0.0722 - val_root_mean_squared_error: 0.0911
# Epoch 128/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0113 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1049 - val_loss: 0.0090 - val_mean_absolute_error: 0.0756 - val_root_mean_squared_error: 0.0931
# Epoch 129/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0114 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1053 - val_loss: 0.0085 - val_mean_absolute_error: 0.0711 - val_root_mean_squared_error: 0.0906
# Epoch 130/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0113 - mean_absolute_error: 0.0810 - root_mean_squared_error: 0.1047 - val_loss: 0.0088 - val_mean_absolute_error: 0.0737 - val_root_mean_squared_error: 0.0922
# Epoch 131/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0113 - mean_absolute_error: 0.0812 - root_mean_squared_error: 0.1049 - val_loss: 0.0086 - val_mean_absolute_error: 0.0726 - val_root_mean_squared_error: 0.0912
# Epoch 132/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0112 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1045 - val_loss: 0.0088 - val_mean_absolute_error: 0.0746 - val_root_mean_squared_error: 0.0924
# Epoch 133/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0111 - mean_absolute_error: 0.0804 - root_mean_squared_error: 0.1040 - val_loss: 0.0087 - val_mean_absolute_error: 0.0728 - val_root_mean_squared_error: 0.0915
# Epoch 134/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0111 - mean_absolute_error: 0.0804 - root_mean_squared_error: 0.1039 - val_loss: 0.0087 - val_mean_absolute_error: 0.0733 - val_root_mean_squared_error: 0.0916
# Epoch 135/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0113 - mean_absolute_error: 0.0813 - root_mean_squared_error: 0.1050 - val_loss: 0.0087 - val_mean_absolute_error: 0.0731 - val_root_mean_squared_error: 0.0917
# Epoch 136/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0112 - mean_absolute_error: 0.0806 - root_mean_squared_error: 0.1044 - val_loss: 0.0086 - val_mean_absolute_error: 0.0714 - val_root_mean_squared_error: 0.0913
# Epoch 137/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0113 - mean_absolute_error: 0.0810 - root_mean_squared_error: 0.1049 - val_loss: 0.0085 - val_mean_absolute_error: 0.0707 - val_root_mean_squared_error: 0.0908
# Epoch 138/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0112 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1045 - val_loss: 0.0085 - val_mean_absolute_error: 0.0716 - val_root_mean_squared_error: 0.0903
# Epoch 139/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0114 - mean_absolute_error: 0.0815 - root_mean_squared_error: 0.1052 - val_loss: 0.0086 - val_mean_absolute_error: 0.0726 - val_root_mean_squared_error: 0.0911
# Epoch 140/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0112 - mean_absolute_error: 0.0810 - root_mean_squared_error: 0.1047 - val_loss: 0.0084 - val_mean_absolute_error: 0.0703 - val_root_mean_squared_error: 0.0901
# Epoch 141/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0110 - mean_absolute_error: 0.0800 - root_mean_squared_error: 0.1037 - val_loss: 0.0087 - val_mean_absolute_error: 0.0705 - val_root_mean_squared_error: 0.0915
# Epoch 142/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0114 - mean_absolute_error: 0.0814 - root_mean_squared_error: 0.1053 - val_loss: 0.0086 - val_mean_absolute_error: 0.0701 - val_root_mean_squared_error: 0.0911
# Epoch 143/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0113 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1049 - val_loss: 0.0086 - val_mean_absolute_error: 0.0724 - val_root_mean_squared_error: 0.0910
# Epoch 144/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0112 - mean_absolute_error: 0.0806 - root_mean_squared_error: 0.1043 - val_loss: 0.0085 - val_mean_absolute_error: 0.0716 - val_root_mean_squared_error: 0.0907
# Epoch 145/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0112 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1045 - val_loss: 0.0086 - val_mean_absolute_error: 0.0724 - val_root_mean_squared_error: 0.0911
# Epoch 146/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0113 - mean_absolute_error: 0.0810 - root_mean_squared_error: 0.1052 - val_loss: 0.0088 - val_mean_absolute_error: 0.0743 - val_root_mean_squared_error: 0.0922
# Epoch 147/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0113 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1048 - val_loss: 0.0086 - val_mean_absolute_error: 0.0724 - val_root_mean_squared_error: 0.0913
# Epoch 148/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0114 - mean_absolute_error: 0.0816 - root_mean_squared_error: 0.1056 - val_loss: 0.0085 - val_mean_absolute_error: 0.0710 - val_root_mean_squared_error: 0.0909
# Epoch 149/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0111 - mean_absolute_error: 0.0803 - root_mean_squared_error: 0.1041 - val_loss: 0.0086 - val_mean_absolute_error: 0.0716 - val_root_mean_squared_error: 0.0911
# Epoch 150/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0111 - mean_absolute_error: 0.0805 - root_mean_squared_error: 0.1042 - val_loss: 0.0086 - val_mean_absolute_error: 0.0719 - val_root_mean_squared_error: 0.0911
# Epoch 151/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0113 - mean_absolute_error: 0.0812 - root_mean_squared_error: 0.1051 - val_loss: 0.0085 - val_mean_absolute_error: 0.0712 - val_root_mean_squared_error: 0.0907
# Epoch 152/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0111 - mean_absolute_error: 0.0805 - root_mean_squared_error: 0.1042 - val_loss: 0.0084 - val_mean_absolute_error: 0.0701 - val_root_mean_squared_error: 0.0902
# Epoch 153/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0113 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1049 - val_loss: 0.0086 - val_mean_absolute_error: 0.0725 - val_root_mean_squared_error: 0.0914
# Epoch 154/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0111 - mean_absolute_error: 0.0802 - root_mean_squared_error: 0.1039 - val_loss: 0.0086 - val_mean_absolute_error: 0.0723 - val_root_mean_squared_error: 0.0912
# Epoch 155/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0111 - mean_absolute_error: 0.0803 - root_mean_squared_error: 0.1041 - val_loss: 0.0085 - val_mean_absolute_error: 0.0710 - val_root_mean_squared_error: 0.0907
# Epoch 156/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0112 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1046 - val_loss: 0.0086 - val_mean_absolute_error: 0.0724 - val_root_mean_squared_error: 0.0914
# Epoch 157/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0112 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1047 - val_loss: 0.0086 - val_mean_absolute_error: 0.0727 - val_root_mean_squared_error: 0.0915
# Epoch 158/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.0111 - mean_absolute_error: 0.0806 - root_mean_squared_error: 0.1043 - val_loss: 0.0085 - val_mean_absolute_error: 0.0712 - val_root_mean_squared_error: 0.0910
# Epoch 159/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0112 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1047 - val_loss: 0.0085 - val_mean_absolute_error: 0.0714 - val_root_mean_squared_error: 0.0907
# Epoch 160/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0110 - mean_absolute_error: 0.0803 - root_mean_squared_error: 0.1037 - val_loss: 0.0085 - val_mean_absolute_error: 0.0699 - val_root_mean_squared_error: 0.0908
# Epoch 161/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0112 - mean_absolute_error: 0.0806 - root_mean_squared_error: 0.1045 - val_loss: 0.0084 - val_mean_absolute_error: 0.0714 - val_root_mean_squared_error: 0.0903
# Epoch 162/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 0.0110 - mean_absolute_error: 0.0803 - root_mean_squared_error: 0.1038 - val_loss: 0.0086 - val_mean_absolute_error: 0.0709 - val_root_mean_squared_error: 0.0915
# Epoch 163/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0111 - mean_absolute_error: 0.0804 - root_mean_squared_error: 0.1041 - val_loss: 0.0085 - val_mean_absolute_error: 0.0705 - val_root_mean_squared_error: 0.0905
# Epoch 164/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0110 - mean_absolute_error: 0.0801 - root_mean_squared_error: 0.1038 - val_loss: 0.0086 - val_mean_absolute_error: 0.0727 - val_root_mean_squared_error: 0.0913
# Epoch 165/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0112 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1045 - val_loss: 0.0085 - val_mean_absolute_error: 0.0708 - val_root_mean_squared_error: 0.0909
# Epoch 166/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0111 - mean_absolute_error: 0.0801 - root_mean_squared_error: 0.1040 - val_loss: 0.0086 - val_mean_absolute_error: 0.0720 - val_root_mean_squared_error: 0.0911
# Epoch 167/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0112 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1046 - val_loss: 0.0085 - val_mean_absolute_error: 0.0722 - val_root_mean_squared_error: 0.0909
# Epoch 168/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0111 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1043 - val_loss: 0.0085 - val_mean_absolute_error: 0.0713 - val_root_mean_squared_error: 0.0908
# Epoch 169/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0111 - mean_absolute_error: 0.0804 - root_mean_squared_error: 0.1042 - val_loss: 0.0085 - val_mean_absolute_error: 0.0706 - val_root_mean_squared_error: 0.0908
# Epoch 170/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0109 - mean_absolute_error: 0.0796 - root_mean_squared_error: 0.1033 - val_loss: 0.0085 - val_mean_absolute_error: 0.0716 - val_root_mean_squared_error: 0.0910
# Epoch 171/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0111 - mean_absolute_error: 0.0804 - root_mean_squared_error: 0.1041 - val_loss: 0.0087 - val_mean_absolute_error: 0.0739 - val_root_mean_squared_error: 0.0919
# Epoch 172/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0112 - mean_absolute_error: 0.0809 - root_mean_squared_error: 0.1046 - val_loss: 0.0087 - val_mean_absolute_error: 0.0711 - val_root_mean_squared_error: 0.0918
# Epoch 173/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0112 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1044 - val_loss: 0.0087 - val_mean_absolute_error: 0.0714 - val_root_mean_squared_error: 0.0919
# Epoch 174/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0111 - mean_absolute_error: 0.0805 - root_mean_squared_error: 0.1042 - val_loss: 0.0085 - val_mean_absolute_error: 0.0722 - val_root_mean_squared_error: 0.0910
# Epoch 175/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0113 - mean_absolute_error: 0.0811 - root_mean_squared_error: 0.1050 - val_loss: 0.0086 - val_mean_absolute_error: 0.0718 - val_root_mean_squared_error: 0.0917
# Epoch 176/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0111 - mean_absolute_error: 0.0804 - root_mean_squared_error: 0.1044 - val_loss: 0.0086 - val_mean_absolute_error: 0.0725 - val_root_mean_squared_error: 0.0916
# Epoch 177/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0112 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1047 - val_loss: 0.0089 - val_mean_absolute_error: 0.0737 - val_root_mean_squared_error: 0.0931
# Epoch 178/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0110 - mean_absolute_error: 0.0800 - root_mean_squared_error: 0.1037 - val_loss: 0.0086 - val_mean_absolute_error: 0.0719 - val_root_mean_squared_error: 0.0914
# Epoch 179/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0111 - mean_absolute_error: 0.0808 - root_mean_squared_error: 0.1044 - val_loss: 0.0087 - val_mean_absolute_error: 0.0710 - val_root_mean_squared_error: 0.0918
# Epoch 180/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0111 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1043 - val_loss: 0.0087 - val_mean_absolute_error: 0.0728 - val_root_mean_squared_error: 0.0919
# Epoch 181/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0110 - mean_absolute_error: 0.0800 - root_mean_squared_error: 0.1036 - val_loss: 0.0085 - val_mean_absolute_error: 0.0704 - val_root_mean_squared_error: 0.0911
# Epoch 182/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.0112 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1046 - val_loss: 0.0087 - val_mean_absolute_error: 0.0722 - val_root_mean_squared_error: 0.0922
# Epoch 183/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0109 - mean_absolute_error: 0.0796 - root_mean_squared_error: 0.1032 - val_loss: 0.0086 - val_mean_absolute_error: 0.0712 - val_root_mean_squared_error: 0.0916
# Epoch 184/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0110 - mean_absolute_error: 0.0802 - root_mean_squared_error: 0.1038 - val_loss: 0.0087 - val_mean_absolute_error: 0.0735 - val_root_mean_squared_error: 0.0921
# Epoch 185/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0111 - mean_absolute_error: 0.0804 - root_mean_squared_error: 0.1040 - val_loss: 0.0087 - val_mean_absolute_error: 0.0722 - val_root_mean_squared_error: 0.0919
# Epoch 186/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0112 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1046 - val_loss: 0.0087 - val_mean_absolute_error: 0.0722 - val_root_mean_squared_error: 0.0921
# Epoch 187/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0109 - mean_absolute_error: 0.0796 - root_mean_squared_error: 0.1032 - val_loss: 0.0089 - val_mean_absolute_error: 0.0732 - val_root_mean_squared_error: 0.0930
# Epoch 188/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0111 - mean_absolute_error: 0.0803 - root_mean_squared_error: 0.1040 - val_loss: 0.0089 - val_mean_absolute_error: 0.0722 - val_root_mean_squared_error: 0.0929
# Epoch 189/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0110 - mean_absolute_error: 0.0798 - root_mean_squared_error: 0.1035 - val_loss: 0.0086 - val_mean_absolute_error: 0.0715 - val_root_mean_squared_error: 0.0917
# Epoch 190/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0111 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1043 - val_loss: 0.0088 - val_mean_absolute_error: 0.0728 - val_root_mean_squared_error: 0.0925
# Epoch 191/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0109 - mean_absolute_error: 0.0798 - root_mean_squared_error: 0.1035 - val_loss: 0.0087 - val_mean_absolute_error: 0.0724 - val_root_mean_squared_error: 0.0919
# Epoch 192/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0108 - mean_absolute_error: 0.0795 - root_mean_squared_error: 0.1030 - val_loss: 0.0089 - val_mean_absolute_error: 0.0737 - val_root_mean_squared_error: 0.0930
# Epoch 193/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0109 - mean_absolute_error: 0.0798 - root_mean_squared_error: 0.1032 - val_loss: 0.0087 - val_mean_absolute_error: 0.0724 - val_root_mean_squared_error: 0.0921
# Epoch 194/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0109 - mean_absolute_error: 0.0799 - root_mean_squared_error: 0.1035 - val_loss: 0.0088 - val_mean_absolute_error: 0.0739 - val_root_mean_squared_error: 0.0927
# Epoch 195/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0109 - mean_absolute_error: 0.0795 - root_mean_squared_error: 0.1031 - val_loss: 0.0089 - val_mean_absolute_error: 0.0739 - val_root_mean_squared_error: 0.0929
# Epoch 196/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0110 - mean_absolute_error: 0.0799 - root_mean_squared_error: 0.1037 - val_loss: 0.0090 - val_mean_absolute_error: 0.0754 - val_root_mean_squared_error: 0.0934
# Epoch 197/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0109 - mean_absolute_error: 0.0800 - root_mean_squared_error: 0.1033 - val_loss: 0.0087 - val_mean_absolute_error: 0.0725 - val_root_mean_squared_error: 0.0918
# Epoch 198/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0110 - mean_absolute_error: 0.0800 - root_mean_squared_error: 0.1039 - val_loss: 0.0089 - val_mean_absolute_error: 0.0726 - val_root_mean_squared_error: 0.0929
# Epoch 199/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0109 - mean_absolute_error: 0.0799 - root_mean_squared_error: 0.1034 - val_loss: 0.0086 - val_mean_absolute_error: 0.0715 - val_root_mean_squared_error: 0.0916
# Epoch 200/200
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0109 - mean_absolute_error: 0.0796 - root_mean_squared_error: 0.1032 - val_loss: 0.0089 - val_mean_absolute_error: 0.0721 - val_root_mean_squared_error: 0.0931
#
# Semua model, history, dan hasil evaluasi disimpan.

# %%
# Evaluasi
print("Making multi-step predictions...")
y_pred_multistep_scaled = model.predict(X_test_seq, verbose=0)
print(f"Prediction shape: {y_pred_multistep_scaled.shape}")

# Langsung pakai data yang sudah normalized (0-1)
y_test_normalized = y_test_seq  # Data test yang sudah dalam bentuk normalized
y_pred_normalized = y_pred_multistep_scaled  # Prediksi yang sudah dalam bentuk normalized

# Hitung multi-step metric pada skala normalized (0-1)
multistep_metrics = calculate_multistep_metrics(y_test_normalized, y_pred_normalized)

# Display results
print("\n" + "=" * 60)
print("=== Hasil Evaluasi MULTI-STEP FORECASTING ===")
print("=" * 60)

print("\n--- Keseluruhan Performa ---")
keseluruhan = multistep_metrics['keseluruhan']
print(f'Mean Absolute Error (MAE):     {keseluruhan["mae"]:.4f}')
print(f'Mean Absolute Percentage Error (MAPE): {keseluruhan["mape"]:.2f}%')
print(f'Root Mean Square Error (RMSE): {keseluruhan["rmse"]:.4f}')
# Out:
# Making multi-step predictions...
# Prediction shape: (1048, 30)
#
# ============================================================
# === Hasil Evaluasi MULTI-STEP FORECASTING ===
# ============================================================
#
# --- Keseluruhan Performa ---
# Mean Absolute Error (MAE):     0.0653
# Mean Absolute Percentage Error (MAPE): 30.31%
# Root Mean Square Error (RMSE): 0.0873

# %%
# Plot training history
plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
